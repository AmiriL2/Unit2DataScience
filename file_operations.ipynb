# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
# This file contains all of the abbreviation for the selected states
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
#open the file to access and read what was inside the file
MyFile = open("states.txt", "r")
#for all the items in the file, print them out
for x in MyFile:
    print(x)
# Out:
# WA
#
# MO
#
# KS
#
# SC
#
# GA
#
# FL
#
# MN
#
# NC
#
# HI
#
# CT
#
# TX
#
# MA
#
# OK
#
# IL
#
# HI
#
# CA
#
# TX
#
# WA
#
# OH
#
# PA
#
# MO
#
# IL
#
# CA
#
# IL
#
# CA
#
# DC
#
# FL
#
# NC
#
# NY
#
# VA
#
# TX
#
# CA
#
# DC
#
# TX
#
# OH
#
# WA
#
# FL
#
# MN
#
# DC
#
# FL
#
# CA
#
# FL
#
# TX
#
# CT
#
# NC
#
# MO
#
# TX
#
# MA
#
# TX
#
# WA
#
# IN
#
# IN
#
# MO
#
# AL
#
# OK
#
# GA
#
# NY
#
# IN
#
# OK
#
# IN
#
# CA
#
# GA
#
# CA
#
# CA
#
# IN
#
# NY
#
# MS
#
# CA
#
# NV
#
# ID
#
# MN
#
# VA
#
# WY
#
# WV
#
# MN
#
# MO
#
# TX
#
# MA
#
# IN
#
# IA
#
# WA
#
# MN
#
# CA
#
# NE
#
# IL
#
# IL
#
# PA
#
# GA
#
# TX
#
# OH
#
# DE
#
# TX
#
# NM
#
# TX
#
# MA
#
# LA
#
# GA
#
# TN
#
# CA
#
# DC
#
# FL
#
# CO
#
# MI
#
# MD
#
# FL
#
# FL
#
# NC
#
# OH
#
# IA
#
# NE
#
# TX
#
# IN
#
# TX
#
# CA
#
# TX
#
# IL
#
# CA
#
# VA
#
# TX
#
# CA
#
# NY
#
# IN
#
# NY
#
# OH
#
# NY
#
# TN
#
# DC
#
# CA
#
# MN
#
# VA
#
# UT
#
# NH
#
# TX
#
# CA
#
# PA
#
# CO
#
# TX
#
# FL
#
# CA
#
# PA
#
# OH
#
# MD
#
# CT
# ...

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
# A bar graph or histogram could be the best to represent the data because it can show all of the times that a specific state repeated
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
# we would need to use the read() function in order to  display them on the histogram
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
#import matplotlib so that you can plot on the graph
import matplotlib.pyplot as PLT 

#some of the states in the list
States = ["NY","NJ", "NC", "SC", "TX", "FL", "ME", "CT", "CA", "OH"]

#set the value for some of the states for when you count the amount of times the state is named
Alabama = 0
Alaska = 0
Arizona = 0
Arkansas = 0
California = 0
Colorodo = 0
Connecticut = 0
Delaware = 0
Florida = 0
Georgia = 0
Hawaii = 0
Idaho = 0
Illinois = 0
Indiana = 0
Iowa = 0
Kansas = 0
Kentucky = 0
Louisiana = 0
Maine = 0
Maryland = 0
Massachusetts = 0
Michigan = 0
Minnesota = 0
Mississippi = 0
Missouri = 0
Montana = 0
Nebraska = 0
Nevada = 0
NewHampshire = 0
NewJersey = 0
NewMexico= 0
NewYork = 0
NorthCarolina = 0
NorthDakota = 0
Ohio = 0
Oklahoma = 0
Oregon = 0
Pennsylvania = 0
RhodeIsland = 0
SouthCarolina = 0
SouthDakota = 0
Tennessee = 0
Texas = 0
Utah = 0
Vermont = 0
Virginia = 0
Washington = 0
WestVirginia = 0
Wisconsin = 0
Wyoming = 0

#open the file so that you can read it
MyFile = open('states.txt' , 'r')

#create another name for the file so that you can call it easier
with open("states.txt" , "r") as MyFile:

#read all of the lines in the file
    for x in MyFile.readlines():
        #if the abbreviation of the state is called on, then add one to the state count
        if x == "AL\n":
            Alabama +=1
        elif x == "AK\n":
            Alaska +=1
        elif x == "AZ\n":
            Arizona +=1
        elif x == "AR\n":
            Arkansas +=1
        elif x == "CA\n":
            California +=1
        elif x == "CO\n":
            Colorodo +=1
        elif x == "CT\n":
            Connecticut +=1
        elif x == "DE\n":
            Delaware +=1
        elif x == "FL\n":
            Florida +=1
        elif x == "GA":
            Georgia+=1
        elif x == "HI\n":
            Hawaii +=1
        elif x == "ID\n":
            Idaho +=1
        elif x == "IL\n":
            Illinois +=1
        elif x == "NY\n":
            NewYork +=1
        elif x == "NJ\n":
            NewJersey +=1
        elif x == "NC\n":
            NorthCarolina +=1
        elif x == "TX\n":
            Texas +=1
        elif x == "SC\n":
            SouthCarolina +=1
        elif x == "OH\n":
            Ohio +=1
        elif x == "ME\n":
            Maine +=1

#the height of the graph depends on the amount of times the state is called on
height = [NewYork, NewJersey, NorthCarolina, SouthCarolina, Texas, Florida, Maine, Connecticut, California, Ohio]

#the amount of states is the width and the amount of times the state was called is the height
PLT.bar(States, height)
#title of the graph
PLT.title('States')
# Out:
# Text(0.5, 1.0, 'States')

# %% [markdown]
# After analyzing all of this data, I can infer that out of all the 10 states that were counted, California (CA) was called on the most with more that 120 times. The second state that is called on the most was Texas(TX) and third state goes to Florida(FL).
