# %% [markdown]
# 1. What was the morality rate in women onboard the titanic?

# %%
# Importing pandas
import pandas as pd
#import matplotlib
import matplotlib.pyplot as PLT

#open and read the file
df = pd.read_csv("titanic.csv")

#define that you only want to takeout the females survival rate on the titanic
FemaleDf = df[df['Sex'] == 'female']

#count the value from survival of females onboard the titanic
Survival = FemaleDf['Survived'].value_counts()

#0 means they died and 1 means they survived
y = Survival[0], Survival[1]

#label the graph
labels = ['Non-Survived', 'Survived']

#make the amount that survived stand out from those who died
explode = (0, 0.1)

#plot on the graph (with extra designs)
PLT.pie(y, labels=labels, explode= explode,autopct='%1.1f%%' )
PLT.title("Morality Rate of Women on Titanic")
# Out:
# Text(0.5, 1.0, 'Morality Rate of Women on Titanic')

# %% [markdown]
# 2. What percentage of people who payed over $37 survived on the titanic

# %%
#separate who payed more than 
Data = df[df['Fare'] >= 37]

#count the amount of people who paye 37+ and lived
Alive = Data['Survived'].value_counts()

#0 means they died and 1 means they survived
J = Alive[0], Alive[1]

#plot title
PLT.title('Who Payed More Than $37 and Survived')

#plot the pie chart
PLT.pie(J,labels=labels,autopct='%1.1f%%' )
# Out:
# ([<matplotlib.patches.Wedge at 0x1288d4eb0>,
# ...
#  [Text(0.40426749832685827, 1.0230189586691656, 'Non-Survived'),
#   Text(-0.4042674025449091, -1.0230189965194159, 'Survived')],
#  [Text(0.22050954454192268, 0.558010341092272, '38.0%'),
#   Text(-0.22050949229722314, -0.5580103617378631, '62.0%')])

# %% [markdown]
# 3. What is the morality rate of those under the age of 18?

# %%
Age = df[df['Age'] < 18]

#count the value from survival of females onboard the titanic
Living = Age['Survived'].value_counts()

#0 means they died and 1 means they survived
y = Living[0], Living[1]

#label the graph
labels = ['Non-Survived', 'Survived']

#title for graph
PLT.title("Morality For Under 18")

#plot on the graph (with extra designs)
PLT.pie(y,labels=labels,autopct='%1.1f%%' )
# Out:
# ([<matplotlib.patches.Wedge at 0x122ea69d0>,
# ...
#  [Text(0.13725967586191265, 1.091402666930168, 'Non-Survived'),
#   Text(-0.1372596758619123, -1.091402666930168, 'Survived')],
#  [Text(0.07486891410649779, 0.5953105455982733, '46.0%'),
#   Text(-0.07486891410649761, -0.5953105455982733, '54.0%')])
