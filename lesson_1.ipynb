# %% [markdown]
# my name is Amiri. I am 17 years old

# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as PLT

y = [1, 2, 3, 4]

x = [22, 34, 94, 12]

PLT.ylabel("Memes")
PLT.xlabel("Trolls")
PLT.title("Test Graph 1")
PLT.plot(x, y)

# %%
#all the different numbers in a graph
y = [56,44]
#this causes it to print out a pie chart
PLT.pie(y)
#put the title of the graph
PLT.title("Who Likes NBA 2K24")
# Out:
# Text(0.5, 1.0, 'Who Likes NBA 2K24')

# %%
#values of the x axis
x =[1, 2, 3,4]
#value of the y axis
y = [12,34,52,67]
# .bar makes it a bar graoh
PLT.bar(x, y)
#label x axis
PLT.xlabel("Bars")
#label y axis
PLT.ylabel("Years")
# Out:
# Text(0, 0.5, 'Years')
