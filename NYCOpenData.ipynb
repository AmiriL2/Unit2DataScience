# %%
# Importing pandas
import pandas as pd
#import matplotlib
import matplotlib.pyplot as PLT

import numpy as np
#open the file
df = pd.read_csv("NYCOpenData.csv")

#testing dataset
df.head()
# Out:
# /var/folders/5m/18_vqpmx55z5x85_w3d9m9600000gp/T/ipykernel_39293/3574853994.py:8: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("NYCOpenData.csv")
#    Fiscal Year  Payroll Number                Agency Name     Last Name  \
# 0         2023            67.0  ADMIN FOR CHILDREN'S SVCS        RUBIEN
# 1         2023            67.0  ADMIN FOR CHILDREN'S SVCS         RUCAS
# 2         2023            67.0  ADMIN FOR CHILDREN'S SVCS         RUCCI
# 3         2023            67.0  ADMIN FOR CHILDREN'S SVCS       RUCHMAN
# 4         2023            67.0  ADMIN FOR CHILDREN'S SVCS  RUDRAKUMARAN
#
#     First Name Mid Init Agency Start Date Work Location Borough  \
# 0      DEBORAH      NaN        06/30/2004             MANHATTAN
# 1  CHRISTOPHER        T        12/07/2020             MANHATTAN
# 2      PATRICK        I        02/04/2019                 BRONX
# 3        ALANE      NaN        08/27/2001             MANHATTAN
# 4  GEETHANJALI        G        12/23/2019             MANHATTAN
#
#                  Title Description Leave Status as of June 30  Base Salary  \
# 0     ADMINISTRATIVE STAFF ANALYST                     CEASED     122349.0
# 1  STRATEGIC INITIATIVE SPECIALIST                     CEASED     115000.0
# 2      CHILD PROTECTIVE SPECIALIST                     CEASED      62137.0
# 3     DIRECTOR OF FIELD OPERATIONS                     ACTIVE     116850.0
# 4            COMMUNITY COORDINATOR                     ACTIVE      68842.0
#
#    Pay Basis  Regular Hours  Regular Gross Paid  OT Hours  Total OT Paid  \
# 0  per Annum         1134.0            76023.92      0.00           0.00
# 1  per Annum          280.0            17643.84      0.00           0.00
# 2  per Annum            0.0             1720.87      0.00         325.62
# 3  per Annum         1820.0           119346.14     14.25         206.53
# 4  per Annum         1820.0            68922.42      6.00         249.49
#
#    Total Other Pay
# 0          1140.16
# 1             0.00
# 2             2.29
# 3            79.27
# 4          3099.00

# %% [markdown]
# 1) What is the average Base Salary for Police Officers from 2015 to 2023?

# %%
#only the Police Department is the Agency we need
PoliceDF = df[df['Agency Name'] == 'POLICE DEPARTMENT']

#want the salary of police officers per year
PoliceDF = PoliceDF[df['Pay Basis'] == 'per Annum']

#want the average base salary
Pay = PoliceDF['Base Salary'].mean()

#average salary of police officers per year
AsOf = PoliceDF.groupby(['Fiscal Year'])['Base Salary'].mean()

PLT.ylabel("Base Salary /Annum")
#plot the graph

#change background color to dark
PLT.style.use('dark_background')
line = AsOf.plot(label='Sine Wave', color='lightblue', linewidth=3, linestyle='-', marker='o', markersize=8)
PLT.title("Average Base Salary From 2015-2023")
AsOf.plot()
# Out:
# /var/folders/5m/18_vqpmx55z5x85_w3d9m9600000gp/T/ipykernel_39293/1560172685.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   PoliceDF = PoliceDF[df['Pay Basis'] == 'per Annum']
# <Axes: title={'center': 'Average Base Salary From 2015-2023'}, xlabel='Fiscal Year', ylabel='Base Salary /Annum'>

# %% [markdown]
# Based on the information displayed on this graph, it can be said that throughout the years there has been a massive increase in the average base salary of police officers, growing from slightly above $68,000/year to around $82,000/year. This is a growth of at minimum 20% from 2015 to 2023.

# %% [markdown]
# 2) What has been the Average Salary Police Officers throughout the different boroughs?

# %%
#only the Police Department is the Agency we need
PoliceDF = df[(df['Agency Name'] == 'POLICE DEPARTMENT') & (df['Pay Basis'] == 'per Annum')]

#groups the average by the average salary of officers throughout the 5 boroughs
Average = PoliceDF.groupby(['Work Location Borough'])['Base Salary'].mean()

#changes background colors 
with PLT.style.context("rose-pine-moon.mplstyle"):
    Average.plot(kind='bar', rot= 45)
PLT.title("Average Base Salary Based on Borough")
# Out:
# Text(0.5, 1.0, 'Average Base Salary Based on Borough')

# %% [markdown]
# Based on what is displayed from this graph, it can be said that Manhattan has the highest base salary per annum for police officers, with an average of around $80,000 per year while the lowest borough is Brooklyn with just under $70,000 per year.

# %% [markdown]
# 3) What is the average Base Salary for Teachers from 2014 to 2023?

# %%
#only the Admin for child services is the Agency we need
TeachersDF = df[df['Agency Name'] == "ADMIN FOR CHILDREN'S SVCS"]

#want the salary of teachers per year
TeachersDF = TeachersDF[df['Pay Basis'] == 'per Annum']

#want the average base salary
Pay = TeachersDF['Base Salary'].mean()

#average salary of teachers per year
AsOf = TeachersDF.groupby(['Fiscal Year'])['Base Salary'].mean()

#label for y-axis
PLT.ylabel("Base Salary /Annum")

#change background color to dark
PLT.style.use('dark_background')

#used to plot the graph, label it, change the color, width, and style
line = AsOf.plot(label='Sine Wave', color='lightblue', linewidth=3, linestyle='-', marker='o', markersize=8)
PLT.title("Average Base Salary From 2014-2023")
# Out:
# /var/folders/5m/18_vqpmx55z5x85_w3d9m9600000gp/T/ipykernel_39293/2972442036.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   TeachersDF = TeachersDF[df['Pay Basis'] == 'per Annum']
# <Axes: title={'center': 'Average Base Salary From 2014-2023'}, xlabel='Fiscal Year', ylabel='Base Salary /Annum'>

# %% [markdown]
# Based on the data shown in the chart above, it can be said that there has been a steady increase of teachers base salary by at least  17% as it has grown from just slightly under $60,000/year to a little over $70,000/year

# %% [markdown]
# What is the average average salary of Police Officers in comparison to Teachers throughout the 5 boroughs

# %%
#only the Police Department is the Agency we need
PoliceDF = df[df['Agency Name'] == 'POLICE DEPARTMENT']

#want the salary of police officers per year
PoliceDF = PoliceDF[df['Pay Basis'] == 'per Annum']

#want the average base salary
Pay = PoliceDF['Base Salary'].mean()

#average salary of police officers per year
AsOf = PoliceDF.groupby(['Fiscal Year'])['Base Salary'].mean()

#only the teachers is the Agency we need
TeachersDF = df[df['Agency Name'] == "ADMIN FOR CHILDREN'S SVCS"]

#want the salary of Teachers per year
TeachersDF = TeachersDF[df['Pay Basis'] == 'per Annum']

#want the average base salary
Pay2 = TeachersDF['Base Salary'].mean()

#average salary of Teachers per year
AsOf2 = TeachersDF.groupby(['Fiscal Year'])['Base Salary'].mean()

fig, ax = PLT.subplots()
# Plot bars for Police Department
ax.bar(AsOf.index, AsOf, width=0.4, color='pink', label='Police Department', )

# Plot bars for Administration for Children's Services
ax.bar(AsOf2.index + 0.4, AsOf2, width=0.4, color='lightblue', label="Admin For Child Services")


# Set labels and title
ax.set_xlabel('Fiscal Year')
ax.set_ylabel('Average Base Salary')
ax.set_title('Average Base Salary Comparison')
ax.legend()
# Show the plot
PLT.show()
# Out:
# /var/folders/5m/18_vqpmx55z5x85_w3d9m9600000gp/T/ipykernel_39293/2341315232.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   PoliceDF = PoliceDF[df['Pay Basis'] == 'per Annum']
# /var/folders/5m/18_vqpmx55z5x85_w3d9m9600000gp/T/ipykernel_39293/2341315232.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   TeachersDF = TeachersDF[df['Pay Basis'] == 'per Annum']

# %% [markdown]
# Based on this information displayed from this graph, it can be said that both Police Officers and Teachers have had a growth in base salary from between 2014 and 2023. Also with what is displayed, it is shown that the difference between the highest base salary in Teachers and base salary in Police Officers is about $10,000. It can also be said that the difference in the lowest base salary in 2014 for teachers in comparison to the lowest in police officers is about %16.
